# %% [markdown]
# ![Parked motorcycle](motorcycle.jpg)
#
# You're working for a company that sells motorcycle parts, and they've asked for some help in analyzing their sales data!
#
# They operate three warehouses in the area, selling both retail and wholesale. They offer a variety of parts and accept credit cards, cash, and bank transfer as payment methods. However, each payment type incurs a different fee.
#
# The board of directors wants to gain a better understanding of wholesale revenue by product line, and how this varies month-to-month and across warehouses. You have been tasked with calculating net revenue for each product line and grouping results by month and warehouse. The results should be filtered so that only `"Wholesale"` orders are included.
#
# They have provided you with access to their database, which contains the following table called `sales`:
#
# ## Sales
# | Column | Data type | Description |
# |--------|-----------|-------------|
# | `order_number` | `VARCHAR` | Unique order number. |
# | `date` | `DATE` | Date of the order, from June to August 2021. |
# | `warehouse` | `VARCHAR` | The warehouse that the order was made from&mdash; `North`, `Central`, or `West`. |
# | `client_type` | `VARCHAR` | Whether the order was `Retail` or `Wholesale`. |
# | `product_line` | `VARCHAR` | Type of product ordered. |
# | `quantity` | `INT` | Number of products ordered. |
# | `unit_price` | `FLOAT` | Price per product (dollars). |
# | `total` | `FLOAT` | Total price of the order (dollars). |
# | `payment` | `VARCHAR` | Payment method&mdash;`Credit card`, `Transfer`, or `Cash`. |
# | `payment_fee` | `FLOAT` | Percentage of `total` charged as a result of the `payment` method. |
#
#
# Your query output should be presented in the following format:
#
# | `product_line` | `month` | `warehouse` |	`net_revenue` |
# |----------------|-----------|----------------------------|--------------|
# | product_one | --- | --- | --- |
# | product_one | --- | --- | --- |
# | product_one | --- | --- | --- |
# | product_one | --- | --- | --- |
# | product_one | --- | --- | --- |
# | product_one | --- | --- | --- |
# | product_two | --- | --- | --- |
# | ... | ... | ... | ... |

# %%
--- Calculated using SQL with conditional filters on client_type = 'Wholesale', and adjusting for transaction fees per payment method. 

SELECT 
	product_line,
    CASE EXTRACT(month FROM date)
           WHEN 6 THEN 'June'
           WHEN 7 THEN 'July'
           WHEN 8 THEN 'August'
       END AS month,
    warehouse,
    CAST(sum(total)-sum(payment_fee) AS NUMERIC) AS net_revenue
FROM sales
WHERE client_type = 'Wholesale'
GROUP BY product_line, warehouse, month
ORDER BY product_line, month, net_revenue DESC;
# Out:
#              product_line   month warehouse  net_revenue
# 0          Braking system  August   Central      3039.41
# 1          Braking system  August      West      2500.67
# 2          Braking system  August     North      1770.84
# 3          Braking system    July   Central      3778.65
# 4          Braking system    July      West      3060.93
# 5          Braking system    July     North      2594.44
# 6          Braking system    June   Central      3684.89
# 7          Braking system    June     North      1487.77
# 8          Braking system    June      West      1212.75
# 9       Electrical system  August     North      4721.12
# 10      Electrical system  August   Central      3126.43
# 11      Electrical system  August      West      1241.84
# 12      Electrical system    July   Central      5577.62
# 13      Electrical system    July     North      1710.13
# 14      Electrical system    July      West       449.46
# ...

# %% [markdown]
# ![revenue by product line](revenue%20by%20product%20line.png)

# %%
--- This chart shows total net revenue per warehouse location. 
--- The Central warehouse clearly outperformed the West and North, indicating stronger sales volume or more favorable payment method distribution. 

--- Calculated using SQL with conditional filters on client_type = 'Wholesale', and adjusting for transaction fees per payment method.

# %% [markdown]
# ![revenue per warehouse](revenue%20per%20warehouse.png)

# %%
SELECT 
    product_line,
    warehouse,
    TO_CHAR(date, 'Month') AS month,
    ROUND(SUM(total) - SUM(payment_fee), 2) AS net_revenue
FROM 
    sales
WHERE 
    client_type = 'Wholesale'
GROUP BY 
    product_line, warehouse, TO_CHAR(date, 'Month')
ORDER BY 
    net_revenue DESC;
# Out:
#              product_line warehouse      month  net_revenue
# 0                  Engine   Central  August         9528.71
# 1            Frame & body   Central  August         8657.99
# 2   Suspension & traction     North  June           8065.74
# 3            Frame & body     North  August         7898.89
# 4                  Engine   Central  June           6548.85
# 5   Suspension & traction   Central  July           6456.72
# 6            Frame & body     North  July           6154.61
# 7       Electrical system   Central  July           5577.62
# 8   Suspension & traction   Central  August         5416.70
# 9            Frame & body   Central  June           5111.34
# 10  Suspension & traction     North  August         4923.69
# 11           Frame & body     North  June           4910.12
# 12      Electrical system     North  August         4721.12
# 13         Braking system   Central  July           3778.65
# 14  Suspension & traction     North  July           3714.28
# ...

# %% [markdown]
# ![revenue per month](revenue%20per%20month.png)
